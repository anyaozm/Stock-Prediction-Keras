# %%
from keras.models import Sequential
from keras.layers import Dense
import pandas as pd
import numpy
# fix random seed for reproducibility
numpy.random.seed(7)
from keras.layers import Dense
import matplotlib.pyplot as plt
from datetime import datetime
# Out:
# /anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation
from keras.layers import Embedding
from keras.layers import LSTM
import numpy as np

# %%
address_1 = '/Users/anyaozmen/Desktop/gsdho.csv'

# %%
# load data
def parse(x):
    return datetime.strptime(x,'%Y-%m-%d')
df = pd.read_csv(address_1,  parse_dates = ['Date'], index_col=0, date_parser=parse)
df
df_p = pd.read_csv(address_1)

# %%
from matplotlib.pyplot import figure
figure(num=None, figsize=(12, 8), dpi=80, facecolor='w', edgecolor='k')
plt.scatter(df_p['Date'],df['High'],color='green')
plt.scatter(df_p['Date'],df['Low'],color='blue')

# %%
plt.scatter(df_p['Date'],df['High'],color='green')
plt.scatter(df_p['Date'],df['Low'],color='blue')

fig_size = plt.rcParams["figure.figsize"]

# %%
plt.plot( 'Date', 'Open', data=df_p, marker='.', markerfacecolor='blue', markersize=12, color='skyblue', linewidth=4)
plt.plot( 'Date', 'Close', data=df_p, marker='.', color='green', linewidth=1)
#plt.plot( 'Date', 'Volume', data=df, marker='', color='olive', linewidth=2, linestyle='dashed')
plt.legend()

# %%
X_train = df[0:30]
y_train = df[30:60]
X_test = df[60:67]
lstm_out = 200
max_features = 2000
# cut texts after this number of words (among top max_features most common words)
maxlen = 80
batch_size = 32

# %%
#MODEL
model = Sequential()
model.add(Dense(32, input_dim= 5, activation='relu'))
model.add(Dense(26, activation='relu'))
model.add(Dense(5, activation='relu'))

# %%
#Compile
model.compile(loss='binary_crossentropy',optimizer='sgd',metrics=['accuracy'])

# %% [markdown]
# model.fit(X_train, y_train,batch_size=batch_size,epochs=15, validation_data=(X_test, y_test))
# score, acc = model.evaluate(X_test, y_test,batch_size=batch_size)

# %%
model.fit(X_train, y_train,batch_size =10, epochs=500)
# Out:
# Epoch 1/500
# 30/30 [==============================] - 0s 283us/step - loss: 18658524.3333 - acc: 0.0000e+00
# Epoch 2/500
# 30/30 [==============================] - 0s 185us/step - loss: 18658524.6667 - acc: 0.0000e+00
# Epoch 3/500
# 30/30 [==============================] - 0s 186us/step - loss: 18658525.3333 - acc: 0.0000e+00
# Epoch 4/500
# 30/30 [==============================] - 0s 184us/step - loss: 18658524.6667 - acc: 0.0000e+00
# Epoch 5/500
# 30/30 [==============================] - 0s 186us/step - loss: 18658524.0000 - acc: 0.0000e+00
# Epoch 6/500
# 30/30 [==============================] - 0s 218us/step - loss: 18658525.3333 - acc: 0.0000e+00
# Epoch 7/500
# 30/30 [==============================] - 0s 363us/step - loss: 18658524.6667 - acc: 0.0000e+00
# Epoch 8/500
# 30/30 [==============================] - 0s 240us/step - loss: 18658524.6667 - acc: 0.0000e+00
# Epoch 9/500
# 30/30 [==============================] - 0s 254us/step - loss: 18658525.3333 - acc: 0.0000e+00
# ...

# %%
#pred
pred = model.predict(X_test)
print(*pred)
# Out:
# [0.66583455 0.67379236 0.         0.         0.        ] [175241.62 151089.55 514081.7  217246.86      0.  ] [214238.58 184711.61 628481.5  265591.28      0.  ] [187292.45 161479.55 549433.4  232186.19      0.  ] [ 387402.6   334009.53 1136468.1   480262.2        0.  ] [148057.6  127652.1  434335.78 183546.83      0.  ] [169911.42 146493.9  498445.12 210638.92      0.  ]
